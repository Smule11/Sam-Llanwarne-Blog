# %% [raw]
# ---
# title: Making a Blog
# author: Sam Llanwarne
# date: '2022-12-19'
# categories: [How To]
# image: jakob-owens-CiUR8zISX60-unsplash.jpg
# format:
#   html:
#     toc: true
# ---

# %% [markdown]
# # Making a Blog
#
# Here I try to succinctly explain how I made this blog...
#
# I am following [Bailey's blog](https://baileyandrew.github.io/Blog/2022tuedec13.html) which has led me on a chain through [fastai's nbdev websites](https://nbdev.fast.ai/tutorials/blogging.html) and ultimately to [Quarto's blogging website](https://quarto.org/docs/websites/website-blog.html).
#
# <details><summary>What are these blogging templates, Jekyll, fastai's nbdev and Quarto?</summary><br>
# <ul>
# Jekyll is Githubs default blogging template. FastAI built FastPages to facilitate notebook embedding in Jekyll blogs. Then Quarto came which is a standalone notebook blogging template. FastAI changed their software to run on Quarto rather than Jekyll. You can access Quarto through FastAI's nbdev package, but I don't need all the nbdev extra features, so am just using Quarto now.
# </ul>
# </details>
#
# Quarto is, at its heart, just software which slightly tidies up R and Python markdown scripts into cleaner documents, for scientific publishing.
#
# -------------------------
#
# <br>
#
# ### <ins>Shorter Instructions (w/o comments)</ins>
#
# <br>
# A) Download and Install a couple of things
#
# <font color=#F87217>I create this .ipynb notebook file, called index.ipynb. </font>
#
# <font color=#F87217>I **installed** [Quarto](https://quarto.org/docs/get-started/)</font>
#
# <font color=#F87217>I **installed** the Quarto extension in [VS Code](https://quarto.org/docs/get-started/hello/vscode.html) </font>
#
# <font color=#F87217>I create an empty github repo online, with no readme file.</font>
#
# <font color=#F87217>I create an empty folder/directory/repo locally/offline with a similar/the same name.</font>
#
# <br>
# B) https://quarto.org/docs/websites/website-blog.html
#
# <font color=#F87217>I open this folder in VS Code and begin to follow the instructions here https://quarto.org/docs/websites/website-blog.html</font>
#
# <font color=#F87217> do ctrl-shit-p and type Quarto Create Project, click it, click create blog, and create a new folder for the blog files. </font>
#
# <font color=#F87217>I then go into the terminal and cd into this new folder, and run these commands, to move the local files online.</font>
#
#
#     git init
#     git add .
#     git commit -m "add my files"
#     git remote add origin <YOUR_NEW_EMPTY_GITHUB_REPO_URL>.git
#     git branch -M main
#     git push -u origin main
#
#
# <font color=#F87217>I add some YAML code in the top cell, to tell the Quarto files how to position the notebook in the website. This YAML cell should be first and of the type Raw. Again see the link above on how to do this. </font>
#
# <font color=#F87217>I then make a folder in the posts folder, and copy this .ipynb notebook file there. It should be called index.ipynb so Quarto knows to publish it.</font>
#
# <br>
# C) <ins>https://quarto.org/docs/publishing/github-pages.html</ins>
#
# <font color=#F87217>I change the _quarto.yml file, to say publish to docs, not in posts. </font>
#
# <font color=#F87217>I make sure I am in the write folder/directory and add a .nojekyll as they say in the link above. </font>
#
# <font color=#F87217>I can push the local changes to github online through VS code.</font>
#
# <font color=#F87217>I change the pages tab in the settings on Github to say publish from the docs folder, making the website go live. </font>
#
# <font color=#F87217>I changed the theme to have a dark and light one, as in the link above.</font>
#
# <font color=#F87217> </font>
#
# <br>
#
# ### <ins>Other blogs</ins>
#
# Creating a blog in a template is easier than coding a website yourself, although I still think this is very easy for a basic website. But incorporating more complex features and making it look nicer is easier with a template. Jekyll is one template people use:
#
# * [Rebecca Stone](https://ysbecca.github.io/) | [github code]()
# * [Mary Paterson] (hyperlink) | [github code]()
# * [Fabian Fuchs](https://fabianfuchsml.github.io/) | [github code]()
#
# But I agreed with Bailey, that doing a template that centres on .ipynb notebooks rather than straight .md markdown files is slightly better, as notebooks include markdown cells, but also code cells. So you can run code offline and the blog post can be more easily code centred. Also other people can copy the notebook and run it themselves which is useful.
#
# A Nbdev Blog
#
# * [Bailey's blog](https://baileyandrew.github.io/Blog/2022tuedec13.html).
#
# A Quarto blog
#
# * [Danielle Navarro](https://blog.djnavarro.net/) | [github code](https://github.com/djnavarro/quarto-blog/)
#     Although she has many (github.io?) websites linking together from [this page](https://djnavarro.net/) | [github code](https://github.com/djnavarro/djnavarro.github.io/blob/main/docs/index.html)
#
# A more homemade blog:
#
# * [Chris Frewin](https://chrisfrew.in/) basically saying:
#     + follow your heart
#     + when you work at a startup you feel a real affinity with for a career
#         - best work, most rewards.
#     + when you work for yourself if you want and you have the drive
#         - most work, variable rewards, potentially v good or v bad.
#     + there's no real reason to work at a big company except it can make you look "good" to other employers
#         - worst work, a consistent but less than average reward.
#
# <br>
#
# ### <ins>Longer Instructions (w/ comments)</ins>
#
# <font color=F87217>I created this notebook file you're reading. (I did this by creating a text file and changing the name from "untitled.txt" to "index.ipynb". Changing the file extension from .txt to .ipynb is important.)</font>
#
# To open and read this .ipynb file I am editing it in Visual Studio Code. (A lot of people use Jupyter Notebook.)
#
# <details><summary><font color=mediumorchid>Following Bailey Blog to build FastAI's nbdev blog (stopped halfway through and changed to pure Quarto)</font></summary><br>
# <ul>
#
# I went to follow [Bailey's blog](https://baileyandrew.github.io/Blog/2022tuedec13.html) which is built using FastAI's nbdev package!
#
# FastAI's nbdev is a package which includes notebook blogging, which is built on Quarto's notebook blogging software. Now FastAI say <font color=blue>Quarto</font> is simpler to use if you only want to blog, although you will miss other nbdev features.
#
# <details><summary><font color=mediumorchid>Failed Quick Attempt Which Almost Worked</font></summary><br>
# <ul>
# <font color=mediumorchid>I tried a quick method to fork [Bailey's github](https://github.com/BaileyAndrew/Blog) to my github, creating a new repo, without installing any nbdev software. </font>
#
# <font color=mediumorchid>I opened github desktop which is connected to my online github account, and chose to clone the online blog repo to a local folder on my computer. Here I can edit the blog files. </font>
#
# I edit the files in VS code. There are many other ways to clone a repository to your local device and edit .ipynb files such as in Jupyter and on Google Colab!
#
# I could do another blog on setting up Github in VS code. Making this blog is a good learning experience with Github too (like any casual sustained effort using something is a good learning experience).
#
# <font color=mediumorchid>I then deleted all the current blog .ipynb files in the Blog folder locally, and inserted this file into the nbs folder. Here in VS code I now stage, commit and push the changes to the online repo. </font>
#
# The main index file, which is the home page, I should edit.
#
# <font color=mediumorchid> I went into the online github repo and the files had been updated. This .ipynb making a blog notebook was there. I then went into settings and on the side found Pages, and chose the branch to make the website active. I chose the main default branch. I refresh the page, the website is live. </font>
#
# BUT... Things did not work 100% because when I was making the .ipynb blog posts I shouldn't just copy Bailey's and make the .ipynb notebooks manually. I should make them with nbdev. This is because the nbdev command to make an ipynb seems to manage and update all the extra files in the repository/folder which embed the notebook in the HTML website.
# </ul>
# </details>
#
# After just trying to clone Bailey's nbdev blog repo, I realised I really should do a new nbdev install to get a new template of the blog in a new repo. When you run new nbdev to populate the empty repo it contains user specific info, so cloning will copy across the old user's name and stuff. Also you need nbdev to create a notebook, as it simultaneously adjusts other files to recognise this new notebook.
#
# <details><summary>Hi Chat_GPT, can you explain what **nbdev_new** is?</summary><br>
# <ul>
# 'nbdev_new' is a command provided by the 'nbdev' library, which is a tool for developing and documenting Python projects using Jupyter notebooks. The 'nbdev_new' command is used to create a new project directory structure and initial configuration files for a project that will be developed with 'nbdev'.
#
# Here is an example of how to use 'nbdev_new' to create a new project:
#
#     $ nbdev_new my_project
#
# This will create a new directory called 'my_project' with the following structure:
#
#     my_project/
#     ├── README.md
#     ├── index.ipynb
#     ├── docs/
#     │   ├── index.ipynb
#     ├── nbdev/
#     │   ├── __init__.py
#     │   ├── core.py
#     │   ├── tests/
#     │   └── ...
#     ├── setup.py
#     └── requirements.txt
#
# The 'README.md' file contains information about your project, and the 'index.ipynb' file is the entry point for your documentation. The 'docs' directory contains the source notebooks for your documentation, and the 'nbdev' directory contains the source code for your project. The 'setup.py' file is used to package your project for distribution, and the 'requirements.txt' file lists the dependencies that your project needs.
#
# You can then use the 'nbdev' library to build and publish your project, as well as to generate documentation from the notebooks in the 'docs' directory.
# </ul>
# </details>
#
# <font color=mediumorchid>I clone the online empty Github repo *notebookBlog* down to my local computer using Github Desktop. </font>
#
# Using Github Desktop to clone a new repo down from Github.com to your local desktop is decently easy, and includes the .git file which connects it with the online branch too which is good.
#
# SO actually I am growing used to using Github Desktop to clone online repos to my local storage now (after a couple of stop-start hesitations). Bailey cloned it down using the terminal and the git command "git clone ..." and this works well too. There are a few other ways to clone an online repo to local storage, the main thing is you want the two folders (online and local offline) to be linked by the .git file.
#
# We need to install nbdev, which contains the python command package **nbdev_new** to instantiate a blog specific to us.
#
# I realise I should have created a new python environment, so I could fully work out which packages are needed (maybe I already have some installed which I won't mention here). But I am just using my main environment which already has some packages/modules installed.
#
# To see more about nbdev, https://pypi.org/project/nbdev/
#
# <font color=mediumorchid>I run **pip install nbdev** in the terminal. </font>
#
# <font color=mediumorchid>Then, still roughly following Bailey's blog, I cd (change directory) into the empty repo/folder in a terminal, and go into python and run the line -
#
# **nbdev_new** </font>
#
# Things don't work and I question what I'm doing and go back to the documentation. Here I realise that I am perhaps unnecessarily going through nbdev to use Quarto, and maybe it is simpler to just use Quarto straight. I give up with nbdev and go to use Quarto. I believe it is a little simpler.
# </ul>
# </details>
#
# <br>
# A) <ins>https://quarto.org/docs/websites/website-blog.html</ins>
#
# I am following the steps in this Quarto Website blog guide.
#
# They say you can use VS Code or the Terminal or RStudio. I use VS Code.
#
# <font color=#F87217>I installed [Quarto](https://quarto.org/docs/get-started/)</font>
#
# (Accidentally to the wrong place on my computer but oh well...)
#
# <font color=#F87217>I installed the Quarto extension in [VS Code](https://quarto.org/docs/get-started/hello/vscode.html) </font>
#
# <font color=#F87217>I create an empty github repo online, with no readme file, named *Sam Llanwarne Blog*.</font>
#
# <font color=#F87217>I create an empty folder/directory/repo locally with a similar/the same name.</font>
#
# <font color=#F87217>I open this folder in VS Code and do ctrl-shit-p and type Quarto Create Project, click it, click create blog, and create a new folder for the blog files. </font>
#
# So we have an online empty git repo, and the blog files offline locally.
#
# <font color=#F87217>I then go into the terminal and cd into this new folder, and run these commands, to move the local files online.
#
#     git init
#     git add .
#     git commit -m "add my files"
#     git remote add origin <YOUR_NEW_EMPTY_GITHUB_REPO_URL>.git
#     git branch -M main
#     git push -u origin main
#
# </font>
#
# I found some of these git commands [here](https://www.techielass.com/convert-a-folder-to-a-git-repository/) and the rest on the github website.
#
# Also, to change hard drive, in a windows terminal I google'd it https://www.digitalcitizen.life/command-prompt-how-use-basic-commands/ and it says just to first type D: or C: to change the drive, and then go **cd *filepath***.
#
# I realised I have to edit the .ipynb notebook file slightly, see here https://quarto.org/docs/tools/vscode.html. I specifically scrolled down to the section on notebooks, Notebook Editor. This gave some of the final information on how to structure the .ipynb or .qmd files.
#
# <font color=#F87217>I add some YAML code in the top cell, to tell the Quarto files how to position the notebook in the website. This YAML cell should be first and of the type Raw. Again see the link above on how to do this. </font>
#
# <font color=#F87217>I then make a folder in the posts folder, and copy this .ipynb notebook file there. It should be called index.ipynb so Quarto knows to publish it.</font>
#
# <br>
# B) <ins>https://quarto.org/docs/publishing/github-pages.html</ins>
#
# Now we're on the Quarto Github Publishing page.
#
# <font color=#F87217>I change the _quarto.yml file, to say publish to docs, not in posts. </font>
#
# <font color=#F87217>I make sure I am in the write folder/directory and add a .nojekyll as they say in the link above. </font>
#
# <font color=#F87217>I can push the local changes to github online through VS code.</font>
#
# I can also preview the changes locally.
#
# The overall plan for managing this blog, is to either make changes locally or online and then commit (and push to the online repo if the changes are local).
#
# I can do a blog on using github in VS code, but not sure 100% how I will frame that, although it will be good.
#
# <font color=#F87217>I change the pages tab in the settings on Github to say publish from the docs folder, making the website go live. </font>
#
# Apparently I should add a .gitignore to ignore a couple of the crazy folders or something, as they might change a lot.
#
# <br>
# C) <ins>https://quarto.org/docs/output-formats/html-themes.html</ins>
# Now I looked at changing the theme.
#
# <font color=#F87217>I changed the theme to have a dark and light one, as in the link above.</font>
#
# Essentially, each post is edited in posts.
#
# The YAML at the top of each .ipynb or .qmd file controls the appearance of that file. e.g.
# * tags
# * contents side bar
# * date
# * blog name
# * potentially the blog summary
# * position of features, colours etc.
#
# You can change the theme, add images and change the layout of the home page easily too.
#
# For example, go into the main homepage index.qmd file, and you can change **type** from default, to grid, to tabel :)
#
# Thanks for reading!
#
# <br>
# <br>
#
# <font color=#F87217> </font>
#
# -------------------------
#
# <font color=#F87217> *Text in this colour are the actions I took* </font>
#
# <font color=mediumorchid> *Text in this colour are obsolete actions I took* </font>
#
# Some useful website links
#
# * [Quarto](https://quarto.org/)
# * [nbdev](https://nbdev.fast.ai/tutorials/blogging.html)
# * [HTML Colours](https://www.computerhope.com/htmcolor.htm)
# * [Unsplash - open source images](https://unsplash.com/photos/CiUR8zISX60)
